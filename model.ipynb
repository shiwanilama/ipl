# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns',None)


data = pd.read_csv('datatouse.csv')
data.shape

data

data.head()

data.columns

data = data[['season', 'id', 'name', 'short_name', 'description', 'home_team',
       'away_team', 'batting_team', 'bowling_team', 'toss_won', 'decision',
       '1st_inning_score', '2nd_inning_score', 'winner', 'result',
       'start_date', 'end_date', 'venue_id', 'venue_name',  'pom', 'points', 'super_over', 'home_overs',
       'home_runs', 'home_wickets', 'home_boundaries', 'away_overs',
       'away_runs', 'away_wickets', 'away_boundaries' 
       ]]


data.head()

data.isna().sum()

data[data['batting_team'].isna()]

na_values = data[data['batting_team'].isna() & data['bowling_team'].isna() & data['home_team'].isna() & data['away_team'].isna() & data['toss_won'].isna() & data['decision'].isna() & data['1st_inning_score'].isna() & data['2nd_inning_score'].isna() & data['venue_name'].isna() & data['winner'].isna() & data['home_overs'].isna() & data['home_runs'].isna() & data['home_overs'].isna() & data['home_boundaries'].isna() & data['home_wickets'].isna() & data['away_runs'].isna() & data['away_overs'].isna() & data['away_wickets'].isna() & data['away_boundaries'].isna()]
na_values.shape

na_values.hist(bins=60, figsize=(20,20))

data

null_val= data[data['batting_team'].isna() & data['bowling_team'].isna() & data['toss_won'].isna() & data['decision'].isna()] 
null_val.shape 

 data = data[~data['batting_team'].isna() & ~data['bowling_team'].isna()]

data.shape

data.isna().sum()

data = data[~data['1st_inning_score'].isna() & ~data['2nd_inning_score'].isna() & ~data['home_overs'].isna() & ~data['home_runs'].isna() & ~data['home_wickets'].isna() & ~data['home_boundaries'].isna() & ~data['away_runs'].isna() & ~data['away_overs'].isna() & ~data['away_wickets'].isna() & ~data['away_boundaries'].isna()]

data.isna().sum()

data.head()

data[['1st_inning_runs', '1st_inning_wickets']] = data['1st_inning_score'].str.split('/', expand=True)
data['1st_inning_runs'] = pd.to_numeric(data['1st_inning_runs'], errors='coerce')
data['1st_inning_wickets'] = pd.to_numeric(data['1st_inning_wickets'], errors='coerce')
# Drop the original '1st_inning_score' column if needed
data = data.drop('1st_inning_score', axis=1)

# Save the updated DataFrame to the same CSV file
data.to_csv('updatedata.csv', index=False)

# Display the updated DataFrame
print(df)

data[['2nd_inning_runs', '2nd_inning_wickets']] = data['2nd_inning_score'].str.split('/', expand=True)
data['2nd_inning_runs'] = pd.to_numeric(data['2nd_inning_runs'], errors='coerce')
data['2nd_inning_wickets'] = pd.to_numeric(data['2nd_inning_wickets'], errors='coerce')
# Drop the original '1st_inning_score' column if needed
data = data.drop('2nd_inning_score', axis=1)

# Save the updated DataFrame to the same CSV file
data.to_csv('updatedata.csv', index=False)

# Display the updated DataFrame
print(df)

df = pd.read_csv('updatedata.csv')
df.shape

df

df['winner'] = df['winner'].str.replace('GT', 'Gujrat Titans')
f
df['winner'] = df['winner'].str.replace('CSK', 'Chennai Super Kings')
f
df['winner'] = df['winner'].str.replace('MI', 'Mumbai Indians')
​
df['winner'] = df['winner'].str.replace('DC', 'Delhi Capitals')
df['winner'] = df['winner'].str.replace('RR', 'Rajasthan Royals')
df['winner'] = df['winner'].str.replace('RCB', 'Royal Challengers Bangalore')
f
df['winner'] = df['winner'].str.replace('KKR', 'Kolkata Knight Riders')
​
f
df['winner'] = df['winner'].str.replace('LSG', 'Lucknow Super Giants')
f
df['winner'] = df['winner'].str.replace('SRH', 'Sunrisers Hyderbad')
f
df['winner'] = df['winner'].str.replace('PBKS', 'Punjab Kings')
​
df.to_csv('updatedata.csv', index=False)
df.to_csv('updatedata.csv', index=False)
df
df

df['toss_won'] = df['toss_won'].str.replace('GT', 'Gujrat Titans')
df['toss_won'] = df['toss_won'].str.replace('CSK', 'Chennai Super Kings')
df['toss_won'] = df['toss_won'].str.replace('MI', 'Mumbai Indians')

df['toss_won'] = df['toss_won'].str.replace('DC', 'Delhi Capitals')

df['toss_won'] = df['toss_won'].str.replace('RR', 'Rajasthan Royals')
df['toss_won'] = df['toss_won'].str.replace('RCB', 'Royal Challengers Bangalore')
df['toss_won'] = df['toss_won'].str.replace('KKR', 'Kolkata Knight Riders')
df['toss_won'] = df['toss_won'].str.replace('LSG', 'Lucknow Super Giants')
df['toss_won'] = df['toss_won'].str.replace('SRH', 'Sunrisers Hyderbad')
df['toss_won'] = df['toss_won'].str.replace('PBKS', 'Punjab Kings')
df.to_csv('updatedata.csv', index=False)
df
df['home_team'] = df['home_team'].str.replace('GT', 'Gujrat Titans')
df['home_team'] = df['home_team'].str.replace('CSK', 'Chennai Super Kings')
df['home_team'] = df['home_team'].str.replace('MI', 'Mumbai Indians')
df['home_team'] = df['home_team'].str.replace('DC', 'Delhi Capitals')
df['home_team'] = df['home_team'].str.replace('RR', 'Rajasthan Royals')
df['home_team'] = df['home_team'].str.replace('RCB', 'Royal Challengers Bangalore')
df['home_team'] = df['home_team'].str.replace('KKR', 'Kolkata Knight Riders')
df['home_team'] = df['home_team'].str.replace('LSG', 'Lucknow Super Giants')
df['home_team'] = df['home_team'].str.replace('SRH', 'Sunrisers Hyderbad')
f['home_team'] = df['home_team'].str.replace('PBKS', 'Punjab Kings')
df.to_csv('updatedata.csv', index=False)
df['away_team'] = df['away_team'].str.replace('GT', 'Gujrat Titans')
df['away_team'] = df['away_team'].str.replace('CSK', 'Chennai Super Kings')
df['away_team'] = df['away_team'].str.replace('MI', 'Mumbai Indians')
df['away_team'] = df['away_team'].str.replace('DC', 'Delhi Capitals')

df['away_team'] = df['away_team'].str.replace('RR', 'Rajasthan Royals')
df['away_team'] = df['away_team'].str.replace('RCB', 'Royal Challengers Bangalore')
df['away_team'] = df['away_team'].str.replace('KKR', 'Kolkata Knight Riders')
df['away_team'] = df['away_team'].str.replace('LSG', 'Lucknow Super Giants')
df['away_team'] = df['away_team'].str.replace('SRH', 'Sunrisers Hyderbad')
df['away_team'] = df['away_team'].str.replace('PBKS', 'Punjab Kings')
df.to_csv('updatedata.csv', index=False)
print(df)
consistent_team = ['Mumbai Indians', 'Chennai Super Kings', 'Gujrat Titans', 'Delhi Capitals', 'Rajsthan Royals', 'Royal Challengers Bangalore', 'Punjab Kings', 'Sunrisers Hyderabad', 'Lucknow Super Giants', 'Kolkata Knight Riders']
df = df[
    (df['batting_team'].isin(consistent_team)) &
    (df['bowling_team'].isin(consistent_team)) &
    (df['home_team'].isin(consistent_team)) &
    (df['away_team'].isin(consistent_team)) &
    (df['toss_won'].isin(consistent_team)) &
    (df['winner'].isin(consistent_team))
]
selected_features = df[['home_team', 'away_team', 'batting_team', 'bowling_team', 'toss_won', 'decision', 
                        '1st_inning_runs', '1st_inning_wickets', '2nd_inning_runs', '2nd_inning_wickets', 'venue_name']]

selected_features = df[['home_team', 'away_team', 'batting_team', 'bowling_team', 'toss_won', 'decision', 
                        '1st_inning_runs', '1st_inning_wickets', '2nd_inning_runs', '2nd_inning_wickets', 'venue_name']]
encode = {'home_team': {'Mumbai Indians':1,'Kolkata Knight Riders':2,'Royal Challengers Bangalore':3,'Delhi Capitals':4,'Chennai Super Kings':5,'Rajasthan Royals':6,'Gujrat Titans':7,'Punjab Kings':8,'Lucknow Super Giants':9,'Sunrisers Hyderabad':10 },
          'away_team': { 'Mumbai Indians':1,'Kolkata Knight Riders':2,'Royal Challengers Bangalore':3,'Delhi Capitals':4,'Chennai Super Kings':5,'Rajasthan Royals':6,'Gujrat Titans':7,'Punjab Kings':8,'Lucknow Super Giants':9,'Sunrisers Hyderabad':10},
          'batting_team': {'Mumbai Indians':1,'Kolkata Knight Riders':2,'Royal Challengers Bangalore':3,'Delhi Capitals':4,'Chennai Super Kings':5,'Rajasthan Royals':6,'Gujrat Titans':7,'Punjab Kings':8,'Lucknow Super Giants':9,'Sunrisers Hyderabad':10},
          'bowling_team': {'Mumbai Indians':1,'Kolkata Knight Riders':2,'Royal Challengers Bangalore':3,'Delhi Capitals':4,'Chennai Super Kings':5,'Rajasthan Royals':6,'Gujrat Titans':7,'Punjab Kings':8,'Lucknow Super Giants':9,'Sunrisers Hyderabad':10},
            'toss_won': {'Mumbai Indians':1,'Kolkata Knight Riders':2,'Royal Challengers Bangalore':3,'Delhi Capitals':4,'Chennai Super Kings':5,'Rajasthan Royals':6,'Gujrat Titans':7,'Punjab Kings':8,'Lucknow Super Giants':9,'Sunrisers Hyderabad':10},
        
         }

# Assuming df is your DataFrame and "venue_name" is the column you want to encode
venue_name_column = df["venue_name"]

# Create a dictionary to map each unique venue_name to a numerical label
venue_name_mapping = {}
encoded_venue_name = []

# Iterate over unique venue_names and assign a unique label to each
for venue_name in venue_name_column.unique():
    if venue_name not in venue_name_mapping:
        venue_name_mapping[venue_name] = len(venue_name_mapping) + 1  # Start labels from 1

# Map the original venue_name values to their corresponding labels
encoded_venue_name = [venue_name_mapping[venue_name] for venue_name in venue_name_column]

# Replace the original column with the encoded values
df["venue_name"] = encoded_venue_name

# Print the encoded values
print(encoded_venue_name)

# Print the venue_name-to-label mapping
print(venue_name_mapping)

# Extract the "decision" column
decision_column = df["decision"]

# Create a dictionary to store the mapping
decision_mapping = {"BAT FIRST": 1, "BOWL FIRST": 2}

# Map the original values to their corresponding labels
encoded_decision = [decision_mapping[value] for value in decision_column]

# Replace the original column with the encoded values
df["decision"] = encoded_decision

# Print the mapping
print(decision_mapping)

# Print the encoded values
print(encoded_decision)

# Assuming 'data' is your DataFrame with features and target variable
# X contains features, and y is the target variable
X = df[['home_team', 'away_team', 'batting_team', 'bowling_team', 'toss_won', 'decision', '1st_inning_runs', '1st_inning_wickets', '2nd_inning_runs', '2nd_inning_wickets', 'venue_name']]
y = df['winner']

# Set a random seed for reproducibility
np.random.seed(42)

# Define the percentage of data to be used for training (e.g., 80%)
train_percentage = 0.8

# Calculate the number of samples for training
num_samples = len(df)
num_train_samples = int(train_percentage * num_samples)

# Generate random indices for training and testing samples
train_indices = np.random.choice(num_samples, size=num_train_samples, replace=False)
test_indices = np.setdiff1d(np.arange(num_samples), train_indices)

# Split the data into training and testing sets
X_train, y_train = X.iloc[train_indices], y.iloc[train_indices]
X_test, y_test = X.iloc[test_indices], y.iloc[test_indices]

# Print the shapes of training and testing sets
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
